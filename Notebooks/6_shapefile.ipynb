# %%
import geopandas as gpd
import pandas as pd
#import earthpy as et
import shapely

# %%
img = "Poligonos/new.shp"
mapa = gpd.read_file(img)
mapa.head()
mapa.plot()
# Out:
# <AxesSubplot:>

# %%
img = "Poligonos/test_mp.shp"
mapa = gpd.read_file(img)
mapa.head()
mapa.plot()
# Out:
# <AxesSubplot:>

# %%
img = "Poligonos/polygon.shp"
mapa = gpd.read_file(img)
mapa.head()
mapa.plot()
# Out:
# <AxesSubplot:>

# %%
img = "Poligonos/bosque.shp"
mapa = gpd.read_file(img)
mapa.head()
mapa.plot()
# Out:
# <AxesSubplot:>

# %%
img = "Poligonos/reforestable.shp"
mapa = gpd.read_file(img)
mapa.head()
mapa.plot()
# Out:
# <AxesSubplot:>
